# %% [markdown]
# # Import Modules and Functions

# %%
import sys, os

#mod_dir = os.path.abspath('/Users/rangulo/projects/EtaCar_LEs/python')
#sys.path.append(mod_dir)

from LC_utility import *

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Read in Data

# %%
## reference tables
table_a57 = pd.read_csv('LC_tables/data/LCref_a57_z.csv')
table_a54 = pd.read_csv('LC_tables/data/LCref_a54_z.csv')

## segment 1
lc_df1 = readin_LCdf('LC_tables/data/LCtable1_z.csv')

## segment 2
lc_df2 = readin_LCdf('LC_tables/data/LCtable2_z.csv')

## segment 3
lc_df3 = readin_LCdf('LC_tables/data/LCtable3_z.csv')

## segment 4
lc_df4 = readin_LCdf('LC_tables/data/LCtable4_z.csv')

# %%
### Some images need to be excluded due to quality
### Images from ccd 54 have bad bands (mainly filter i is affected)

bad_expnums_a54z = pd.read_csv('txt_files/a54z_badims.csv')['a54'].values
bad_expnums_a57z = pd.read_csv('txt_files/a57z_badims.csv')['a57'].values

# bad_expnums_a54z = None
# bad_expnums_a57z = None

# %% [markdown]
# # Combine LCs

# %% [markdown]
# ### Fitting Process for Each Segment

# %%
# ### Define uncertainty/error cut on flux error

f_lim = 50.0               # upper limit of flux (muJyas2)
ferr_lim = 1.0            # upper limit of flux error (muJyas2_err)

# ### The working indices for fitting process -- run before the rest
bin_sz = None
flag_inds(lc_df1, f_lm=f_lim, ferr_lm=ferr_lim, bad_expnums=bad_expnums_a57z, bin_size=bin_sz)
flag_inds(lc_df2, f_lm=f_lim, ferr_lm=ferr_lim, bad_expnums=bad_expnums_a54z, bin_size=bin_sz)
flag_inds(lc_df3, f_lm=f_lim, ferr_lm=ferr_lim, bad_expnums=bad_expnums_a54z, bin_size=bin_sz)
flag_inds(lc_df4, f_lm=f_lim, ferr_lm=ferr_lim, bad_expnums=bad_expnums_a54z, bin_size=bin_sz)
# Out:
# 'Updated LC dataframe -- flagged working indices'

# %%
### Fit LCs to a template
### 1st iteration --> template is an individual LC


### Use same tshifts as in filter i
iparms1 = pd.read_csv('LC_tables/fit_params/fparams_i1.csv').values
iparms2 = pd.read_csv('LC_tables/fit_params/fparams_i2.csv').values
iparms3 = pd.read_csv('LC_tables/fit_params/fparams_i3.csv').values
iparms4 = pd.read_csv('LC_tables/fit_params/fparams_i4.csv').values


## segment 1
templ_ID1 = 2
fit_parms1 = fit_LCs(lc_df1, templ_ID=templ_ID1, tshift_ls=iparms1[1])

## segment 2
templ_ID2 = 34
fit_parms2 = fit_LCs(lc_df2, templ_ID=templ_ID2, tshift_ls=iparms2[1])

## segment 3
templ_ID3 = 90
fit_parms3 = fit_LCs(lc_df3, templ_ID=templ_ID3, tshift_ls=iparms3[1])

## segment 4
templ_ID4 = 0
fit_parms4 = fit_LCs(lc_df4, templ_ID=templ_ID4, tshift_ls=iparms4[1])

# %%
### Create data frame of aligned and combined LCs

## segment 1
comb1 = get_combLCs(lc_df1, fit_parms1)

## segment 2
comb2 = get_combLCs(lc_df2, fit_parms2)

## segment 3
comb3 = get_combLCs(lc_df3, fit_parms3)

## segment 4
comb4 = get_combLCs(lc_df4, fit_parms4)

# %%
### Get LC curve fit

## segment 1
c_t1, c_mu1, c_std1 = get_LCfit(comb1, metric=5e4)

## segment 2
c_t2, c_mu2, c_std2 = get_LCfit(comb2, metric=5e4)

## segment 3
c_t3, c_mu3, c_std3 = get_LCfit(comb3, metric=5e4)

## segment 4
c_t4, c_mu4, c_std4 = get_LCfit(comb4, metric=5e4)

# %%
#df = lc_df1.t[lc_df1.t['ID']==2]


lc_ids, tshifts, a_norms, b_offsets = fit_parms1

t_all = []
f_all = []
ferr_all = []
for i in [0, 1, 2, 3, 4, ]:

    df = lc_df1.t[lc_df1.t['ID']==i]
    
    #-----
    idx = df.g_ixs_flag
    
    x = df.mjd[idx]
    
    y = df.muJyas2[idx]
    
    yerr = df.muJyas2_err[idx]

    err_th = 0.76
    x = x[yerr<err_th]
    y = y[yerr<err_th]
    yerr = yerr[yerr<err_th]
    

    tshift = tshifts[i]
    a_norm = a_norms[i]
    b_offset = b_offsets[i]
    
    plt.errorbar(x-tshift, y
                 *a_norm + b_offset, fmt='.', ecolor='r', markersize=5, label=i)
    #plt.plot(x-tshift, y*a_norm + b_offset, '.', label=i)

    t_all.append(x-tshift)
    f_all.append(y*a_norm + b_offset)
    ferr_all.append(a_norm*yerr)

plt.legend()



#plt.xlim([56000, 59000])
#plt.ylim([-2.5, 3])

# %%
t_all = np.concatenate(t_all)
f_all = np.concatenate(f_all)
ferr_all = np.concatenate(ferr_all)

# %%
#-----

x = t_all

y = f_all

yerr = ferr_all


#x = comb_df.t.loc[inds,'mjd']
#y = comb_df.t.loc[inds,'muJyas2']
#yerr = comb_df.t.loc[inds,'muJyas2_err']

kernel = ExpSquaredKernel(metric=3e4)
gp = george.GP(kernel)
gp.compute(x, yerr)


t = np.linspace(min(x), max(x), 5000)
mu, cov = gp.predict(y, t)
std = np.sqrt(np.diag(cov))

plt.fill_between(t, mu-std, mu+std, alpha=0.5, color='r', edgecolor='blue', )

plt.plot(x, y, '.', markersize=5)

# %%
df = lc_df2.t[lc_df2.t['g_ixs_flag']]

# %%
df
# Out:
#       ID     x    y  bsize           mjd     zpt  fluxADU  flux_err  X2norm  \
# 0     30  4011  816      3  56341.289265  30.915  -677.61     10.80    1.83
# 1     30  4011  816      3  56341.291336  30.915  -653.43     10.46    1.11
# 2     30  4011  816      3  56360.209714  30.915  -653.42     12.51    0.80
# 4     30  4011  816      3  56487.988309  30.915  -633.86      9.90    1.65
# 5     30  4011  816      3  56488.988287  30.915  -651.75     10.42    0.82
# ...   ..   ...  ...    ...           ...     ...      ...       ...     ...
# 4968  67  3966  996      3  59948.227068  30.915  -663.55     16.78    1.74
# 4969  67  3966  996      3  60126.974862  30.915  -733.43     22.89    3.29
# 4970  67  3966  996      3  60156.989461  30.915  -769.24     25.32    1.43
# 4973  67  3966  996      3  60486.991345  30.296  -381.10      8.03    1.30
# 4974  67  3966  996      3  60508.013890  30.272  -389.30     13.53    0.39
#
#       Npix  ...  FSCAT00   FWHM  M5SIGMA  SKYADU  muJyas2 muJyas2_err  \
# 0        9  ...    0.084  4.678   22.854  3319.0   -14.53      0.2315
# 1        9  ...    0.081  4.272   22.891  3368.0   -14.01      0.2243
# 2        9  ...    0.172  2.985   23.119  1729.0   -14.01      0.2683
# 4        9  ...    0.136  4.132   22.883  6362.0   -13.59      0.2123
# 5        9  ...    0.139  3.539   23.022  7003.0   -13.98      0.2234
# ...    ...  ...      ...    ...      ...     ...      ...         ...
# 4968     9  ...    0.137  3.614   22.552  2641.0   -14.23      0.3598
# 4969     9  ...    0.137  3.114   22.308  7674.0   -15.73      0.4908
# 4970     9  ...    0.085  4.474   21.851  7125.0   -16.50      0.5430
# 4973     9  ...    0.070  5.071   22.396  2469.0   -14.45      0.3045
# 4974     9  ...    0.046  4.761   21.822  7694.0   -15.10      0.5248
#
#      g_ixs_flag       new_mjd new_muJyas2 new_muJyas2_err
# 0          True  56187.753406  -48.833105        0.438123
# 1          True  56187.755477  -47.848985        0.424496
# 2          True  56206.673855  -47.848985        0.507768
# 4          True  56334.452450  -47.054119        0.401786
# 5          True  56335.452428  -47.792209        0.422793
# ...         ...           ...         ...             ...
# 4968       True  59974.784622  -34.729599        0.829353
# 4969       True  60153.532416  -38.187158        1.131313
# 4970       True  60183.547015  -39.962037        1.251636
# 4973       True  60513.548899  -35.236708        0.701884
# 4974       True  60534.571444  -36.734983        1.209684
#
# [4189 rows x 33 columns]

# %%
df.columns
# Out:
# Index(['ID', 'x', 'y', 'bsize', 'mjd', 'zpt', 'fluxADU', 'flux_err', 'X2norm',
#        'Npix', 'Nmask', 'Jyas2', 'Jyas2_err', 'SB', 'SB_err', 'fitsfile',
#        'skip', 'imID', 'filter', 'CONVOL00', 'PHOTNORM', 'KSUM00', 'FSIG00',
#        'FSCAT00', 'FWHM', 'M5SIGMA', 'SKYADU', 'muJyas2', 'muJyas2_err',
#        'g_ixs_flag', 'new_mjd', 'new_muJyas2', 'new_muJyas2_err'],
#       dtype='object')

# %%
plt.plot(df.new_mjd, df.X2norm, '.')

plt.xlim([56000, 61000])

plt.xlim
# Out:
# (56000.0, 61000.0)

# %%
plt.plot(df.new_mjd, df.new_muJyas2_err, '.')

plt.xlim([56000, 61000])
# Out:
# (56000.0, 61000.0)

# %%
plt.plot(df.new_mjd, df.M5SIGMA, '.')

# %%
plt.errorbar(df.new_mjd, df.new_muJyas2, df.new_muJyas2_err, fmt='.')

plt.xlim([56000, 61000])
# Out:
# (56000.0, 61000.0)

# %%
df.columns
# Out:
# Index(['ID', 'x', 'y', 'bsize', 'mjd', 'zpt', 'fluxADU', 'flux_err', 'X2norm',
#        'Npix', 'Nmask', 'Jyas2', 'Jyas2_err', 'SB', 'SB_err', 'fitsfile',
#        'skip', 'imID', 'filter', 'CONVOL00', 'PHOTNORM', 'KSUM00', 'FSIG00',
#        'FSCAT00', 'FWHM', 'M5SIGMA', 'SKYADU', 'muJyas2', 'muJyas2_err',
#        'g_ixs_flag', 'new_mjd', 'new_muJyas2', 'new_muJyas2_err'],
#       dtype='object')

# %%
df[df.new_muJyas2<-80]['KSUM00']
# Out:
# 3375    1.1387
# Name: KSUM00, dtype: float64

# %% [markdown]
# ### See/Check Fitting Process

# %%
### See individual LCs

## 4 segments (labelled 1-4)

# plot_lcs(lc_df1)
# plot_lcs(lc_df4, plot_orig=True)
# plot_lcs(lc_df1, plt_xl=60400)

# %%
### Check how peaks are found

# ch_df = lc_df1
# lc_ids = np.unique(ch_df.t['ID'])
# for i in lc_ids: 
#     check_inds = np.where(ch_df.t['ID'].eq(i) & ch_df.t['g_ixs_flag'].eq(True))[0]
#     ch_t, ch_mu, ch_std = get_LCfit(ch_df,indices=check_inds, metric=1e5)

#     plt.scatter(ch_df.t.loc[check_inds,'mjd'], ch_df.t.loc[check_inds,'muJyas2'])
#     plt.scatter(ch_t,ch_mu)

#     tpeak = find_t_peak(ch_t,ch_mu,ch_std, metric=None)
#     # tpeak = find_t_peak(ch_t,ch_mu,ch_std, metric=None, t_range=[57000,57900])
#     # plt.axvline(tpeak)
    
#     plt.show()

# %%
### See Fitting Process

# df = lc_df1
# fit_ps = fit_parms1
# t_ID = templ_ID1

# plot_LCfits(df,fit_ps, templ_ID=t_ID)

# %%
### See comb LCs

# df = lc_df3
# fit_ps = fit_parms3
# t_ID = templ_ID3

# for i in fit_ps[0]:
#     df_inds = get_LCinds(df, lc_ID=i)
#     plt.errorbar(df.t.loc[df_inds,'new_mjd'], df.t.loc[df_inds,'new_muJyas2'], yerr=df.t.loc[df_inds,'new_muJyas2_err'], fmt='.-', ecolor='black')

# %%
### See combined LC

# c_df = comb2
# t_mns = c_t2
# f_mns = c_mu2
# f_mers = c_std2

# plt.errorbar(c_df.t['mjd'], c_df.t['muJyas2'], fmt='.', color='blue', alpha=0.25)
# plt.axhline(y=0, linestyle='--', color='black')
# plt.errorbar(t_mns, f_mns, fmt='--.', ecolor='black', color='orange') #,yerr=f_mers

# plt.xlabel('MJD')
# plt.ylabel('$\mu$Jy/as$^2$')
# plt.show()

# %% [markdown]
# # Model LC

# %% [markdown]
# ### Combine Segments

# %%
### Fit segments with overlap

# Use same timeshifts as in filter i
tshiftsm_i = pd.read_csv('LC_tables/fit_params/mtshifts_i1.csv')['tshift'].values

tshiftm21, am21, bm21 = get_tshift_scale_offset(c_t2, c_mu2, c_std2, c_t1, c_mu1, c_std1, tshift_d=tshiftsm_i[0])

tshiftm23, am23, bm23 = get_tshift_scale_offset(c_t2, c_mu2, c_std2, c_t3, c_mu3, c_std3, tshift_d=tshiftsm_i[2])


# # fit segment 4 to segment 3 after its been fitted to segment 2
# m_t3 = c_t3-tshiftm23
# m_f3 = am23*c_mu3+bm23
# m_ferr3 = am23*c_std3

# tshiftm34, am34, bm34 = get_tshift_scale_offset(m_t3, m_f3, m_ferr3, c_t4, c_mu4, c_std4, tshift_d=tshiftsm_i[3])


## Fitting is not getting tail to dip below quiescent flux
tshiftm34 = tshiftsm_i[3]
# am34 = 2.5
# bm34 = -41.

## by normalization test
# am34 = 2.75
# bm34 = -41.1

## Case 1
am34 = 2.9
bm34 = -41.2
## Case 2
# am34 = 3.0
# bm34 = -41.3
## Case 3
# am34 = 3.1
# bm34 = -41.4


# ## From running with bad images
# tshiftm21 = tshiftsm_i[0]
# am21 = 4.72
# bm21 = -52.39

# tshiftm23 = tshiftsm_i[2]
# am23 = 2.54
# bm23 = -36.59

# tshiftm34 = tshiftsm_i[3]
# am34 = 1.93
# bm34 = -40.95

# %%
print(tshiftm34, am34, bm34)
# Out:
# -4450.0 2.9 -41.2

# %%
### Combine Segments
    ## Combine model data

# offsetm = 56.7       # look at plot to decide
# offsetm = 57.75

## Case 1
offsetm = 59.4
## Case 2
# offsetm = 59.9
## Case 3
# offsetm = 60.6


m_t1 = c_t1-tshiftm21
m_f1 = (am21*c_mu1+bm21)+offsetm
m_ferr1 = am21*c_std1

m_t2 = c_t2
m_f2 = c_mu2+offsetm
m_ferr2 = c_std2

m_t3 = c_t3-tshiftm23
m_f3 = (am23*c_mu3+bm23)+offsetm
m_ferr3 = am23*c_std3

m_t4 = c_t4-tshiftm34
m_f4 = (am34*c_mu4+bm34)+offsetm
m_ferr4 = am34*c_std4

# %%
### Combine Segments
    ## Combine LC data

fin_t1 = comb1.t['mjd'].values-tshiftm21
fin_f1 = (am21*comb1.t['muJyas2'].values+bm21)+offsetm
fin_ferr1 = am21*comb1.t['muJyas2_err'].values

fin_t2 = comb2.t['mjd'].values
fin_f2 = comb2.t['muJyas2'].values+offsetm
fin_ferr2 = comb2.t['muJyas2_err'].values

fin_t3 = comb3.t['mjd'].values-tshiftm23
fin_f3 = (am23*comb3.t['muJyas2'].values+bm23)+offsetm
fin_ferr3 = am23*comb3.t['muJyas2_err'].values

fin_t4 = comb4.t['mjd'].values-tshiftm34
fin_f4 = (am34*comb4.t['muJyas2'].values+bm34)+offsetm
fin_ferr4 = am34*comb4.t['muJyas2_err'].values


tls_m = np.concatenate([fin_t1, fin_t2, fin_t3, fin_t4])
fls_m = np.concatenate([fin_f1, fin_f2, fin_f3, fin_f4])
ferrls_m = np.concatenate([fin_ferr1, fin_ferr2, fin_ferr3, fin_ferr4])

ord_inds_m = tls_m.argsort()
tls_m = tls_m[ord_inds_m]
fls_m = fls_m[ord_inds_m]
ferrls_m = ferrls_m[ord_inds_m]

comb_m_data = {'mjd': tls_m, 'muJyas2': fls_m, 'muJyas2_err': ferrls_m}
comb_m = pdastrostatsclass()
comb_m.t = comb_m.t.assign(**comb_m_data)

## Save table for bookkeeping purposes
comb_m.t.to_csv('LC_tables/models/zLC_data1.csv', index=False)

# %%
### Create the model (LC_0)

m_t, m_mu, m_std = get_LCfit(comb_m, metric=3e4)

lc_model = {'mjd':m_t, 'muJyas2':m_mu, 'muJyas2_err':m_std}
lc_model_d = pd.DataFrame(lc_model)

lc_model_d.to_csv('LC_tables/models/zLC_m1.csv', index=False)

# %% [markdown]
# ### See Model Fitting

# %%
### Individual Segements

# fig, axs = plt.subplots(4,1, dpi = 100, figsize = [8,8], sharex=True)

# axs = axs.flatten()
# axs[3].set_xlabel('MJD (days)')

# axs[0].errorbar(c_t1, c_mu1, yerr=c_std1, fmt='--o', ecolor='black', color='deepskyblue', label='Loc 1')
# axs[1].errorbar(c_t2, c_mu2, yerr=c_std2, fmt='--o', ecolor='black', color='mediumseagreen', label='Loc 2')
# axs[2].errorbar(c_t3, c_mu3, yerr=c_std3, fmt='--o', ecolor='black', color='red', label='Loc 3')
# axs[3].errorbar(c_t4, c_mu4, yerr=c_std4, fmt='--o', ecolor='black', color='orange', label='Loc 4')

# for ax in axs:
#     ax.minorticks_on()
#     ax.tick_params(axis='x', labelsize=12)
#     ax.tick_params(axis='y', labelsize=12)
#     ax.tick_params(which='major',bottom='on',top='on',left='on',right='on',length=8)
#     ax.tick_params(which='minor',bottom='on',top='on',left='on',right='on',length=3)
#     ax.set_ylabel('$\mu$Jy/as$^2$', fontsize = 14)
#     ax.legend(fontsize = 14)


# # axs[1].axvline(find_t_peak(c_t2,c_mu2,c_std2, metric=None, t_range=[59000,60000]))
# # axs[2].axvline(find_t_peak(c_t3,c_mu3,c_std3, metric=None, t_range=[57000,57800]))

# # pl_fig.savefig('../figures/display/EtaCar_PiecesM.png', bbox_inches = 'tight', dpi=100)

# %%
### See Connected Segments

fig, ax = plt.subplots(dpi = 100, figsize = [8,5])
ax.minorticks_on()
ax.tick_params(axis='x', labelsize=12)
ax.tick_params(axis='y', labelsize=12)
ax.tick_params(which='major',bottom='on',top='on',left='on',right='on',length=12)
ax.tick_params(which='minor',bottom='on',top='on',left='on',right='on',length=5)
ax.set_xlabel('MJD (days)', fontsize = 14)
ax.set_ylabel('$\mu$Jy/as$^2$', fontsize = 14)
ax.ticklabel_format(axis='both', style='plain')


ax.errorbar(m_t1, m_f1, yerr=m_ferr1, fmt='--.', ecolor='black', color='deepskyblue', label='Loc 1')
ax.errorbar(m_t2, m_f2, yerr=m_ferr2, fmt='--.', ecolor='black', color='mediumseagreen', label='Loc 2')
ax.errorbar(m_t3, m_f3, yerr=m_ferr3, fmt='--.', ecolor='black', color='red', label='Loc 3')
ax.errorbar(m_t4, m_f4, yerr=m_ferr4, fmt='--.', ecolor='black', color='orange', label='Loc 4')

ax.axhline(y=0, ls='--', color='k')

#fig.savefig(f"update/{am34}_fitting_check.png", bbox_inches = 'tight', dpi=100)

# %%
### Plot Model
plt.subplots(dpi = 100, figsize = [12,6])
plt.errorbar(comb_m.t['mjd'], comb_m.t['muJyas2'], fmt='.', ecolor='black', color='blue')
plt.errorbar(m_t, m_mu, fmt='--.', ecolor='black', color='orange')
plt.axhline(y=0, linestyle='--', color='black')
# plt.ylim(-3,15)
