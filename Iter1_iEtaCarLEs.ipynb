                "ec0915.250504.1384051_ooi_i_v1_N22.sw.fits", "ec0915.250506.1384895_ooi_i_v1_N22.sw.fits", "ec0915.250506.1384901_ooi_i_v1_N22.sw.fits", 
                "ec0915.250515.1385486_ooi_i_v1_N22.sw.fits", "ec0915.250516.1385993_ooi_i_v1_N22.sw.fits", "ec0915.250524.1389974_ooi_i_v1_N22.sw.fits", 
                "ec0915.250524.1389978_ooi_i_v1_N22.sw.fits", "ec0915.250530.1391883_ooi_i_v1_N22.sw.fits"]

bad_expnums_i = [float(re.search('\.(\d+)_ooi_',os.path.basename(im)).groups()[0]) for im in bad_images_i]
# bad_expnums_i = None

# %% [markdown]
# # Combine LCs of different segments

# %% [markdown]
# ### Segment 1

# %%
### Read in light curves -- ec0915 ccd 57, focused on before big peak

# url1 = 'https://stsci-transients.stsci.edu/eta/etalc/results/rod_test/goodpos_i/ec0915/57/ec0915a57_goodpos_i_tmpl403910.html'
# html1 = requests.get(url1).content
# df_table1 = pd.read_html(html1)[-1]

url1 = 'https://stsci-transients.stsci.edu/eta/etalc/results/rod_test/goodpos_i/ec0915/57/ec0915a57_goodpos_i_tmpl523435.html'
html1 = requests.get(url1).content
df_table1 = pd.read_html(html1)[-1]

groups1 = [0, 1]
## 0 - main, 1 - secondary

df_list1 = []
df_table1_inds1 = []
for i in range(len(df_table1[:6])):
    group_i = df_table1['group'][i]
    ID_i = df_table1['ID'][i]

    if group_i == 0:
        url = 'https://stsci-transients.stsci.edu/eta/etalc/results/rod_test/goodpos_i/ec0915/57/ec0915a57_goodpos_i_tmpl523435_ID'+str(ID_i)+'_lc.txt'
        temp_tab = pd.read_csv(url, sep='\s+')
        df_list1.append(temp_tab)
        df_table1_inds1.append(i)


### Want to work with micro-Jansky
for df in df_list1:
    df['mJyas2'] = df['Jyas2']*1e6
    df['mJyas2_err'] = df['Jyas2_err']*1e6

# %%
### Loop through and see the individual light curves
### Figure out uncertainty cuts to find the peaks

# n_sigs1 = None
n_sigs1 = [3.0,1.0]         # n-sigma cuts based on micro-Jyas2 and its error
mJyas2_lms1 = None
# mJyas2_lms1 = [50.0,1.0]  # upperlimits on micro-Jyas2 and its error


# for df in df_list1:
#     print(df['ID'][0])
    
#     # plt.errorbar(df['mjd'], df['mJyas2'], yerr=df['mJyas2_err'], fmt='o', ecolor='black', color='blue')

#     inds_sig = lc_indices(df, n_sigmas=n_sigs1, mJyas2_lms=mJyas2_lms1)
#     plt.errorbar(df['mjd'][inds_sig], df['mJyas2'][inds_sig], yerr=df['mJyas2_err'][inds_sig], fmt='--o', ecolor='black', color='orange')
    
#     plt.axhline(y=0, linestyle='--', color='black')

#     # peak_t1 = find_t_peak(df['mjd'][inds_sig].values, df['Jyas2'][inds_sig].values)
#     # plt.axvline(x=peak_t1,color='red')
    
#     plt.show()

# %%
# Find the shift and fitting parameters for each light curve compared to the first one
temp_i = np.where(df_table1.loc[df_table1_inds1,'ID']==5)[0][0]
temp_ID = df_list1[temp_i]['ID'][0]          # just to confirm indices
g1_inds = lc_indices(df_list1[temp_i], n_sigmas=n_sigs1, mJyas2_lms=mJyas2_lms1)
t1 = df_list1[temp_i]['mjd'][g1_inds].values
f1 = df_list1[temp_i]['mJyas2'][g1_inds].values
f1_err = df_list1[temp_i]['mJyas2_err'][g1_inds].values


fig, axs = plt.subplots(3, 5, figsize=(20, 10))
axs = axs.flatten() 

tshifts_57 = []
a_norms_57 = []
b_offsets_57 = []

for i, df in enumerate(df_list1):
    g_inds = lc_indices(df, n_sigmas=n_sigs1, mJyas2_lms=mJyas2_lms1)
    t2 = df['mjd'][g_inds].values
    f2 = df['mJyas2'][g_inds].values
    f2_err = df['mJyas2_err'][g_inds].values

    tshift, a, b = get_tshift_scale_offset(t1, f1, f1_err, t2, f2, f2_err)

    tshifts_57.append(tshift)
    a_norms_57.append(a)
    b_offsets_57.append(b)
    
    ax = axs[i]
    ax.plot(t1, f1, label='lc tmp')
    ax.errorbar(t2, f2, label='lc', fmt='.-')
    ax.errorbar(t2-tshift, f2*a + b, alpha=.5, label='lc aligned', fmt='.-')

    #-------
    # ax.axvline(x=57452, color='k', linewidth=.2)
    # ax.axvline(x=56745, color='k', linewidth=.2, label='tmpl')
    ax.axhline(y=0, color='k', linewidth=.2)

    i_ID = str(df['ID'][0])
    ax.legend()
    ax.set_title(f'ID={i_ID}')

plt.show()

# %%
for i in range(len(tshifts_57)):
    df = df_list1[i]
    i_inds = lc_indices(df, n_sigmas=n_sigs1, mJyas2_lms=mJyas2_lms1)
    
    tshift_i = tshifts_57[i]
    a_i = a_norms_57[i]
    b_i = b_offsets_57[i]
    
    t_new = df['mjd'][i_inds] - tshift_i
    f_new = a_i*df['mJyas2'][i_inds]+b_i
    ferr_new = a_i*df['mJyas2_err'][i_inds]
    df.loc[i_inds,'new_mjd_1'] = t_new
    df.loc[i_inds,'new_mJyas2_1'] = f_new
    df.loc[i_inds,'new_mJyas2_err_1'] = ferr_new

    # t_new = df['mjd'] - tshift_i
    # f_new = a_i*df['mJyas2']+b_i
    # ferr_new = a_i*df['mJyas2_err']
    # df['new_mjd_1'] = t_new
    # df['new_mJyas2_1'] = f_new
    # df['new_mJyas2_err_1'] = ferr_new
    
    plt.errorbar(t_new, f_new, yerr=ferr_new, fmt='.-', ecolor='black')
    # plt.ylim(-3.0e-6,4.0e-6)
    # plt.xlim(57650,57800)

# %%
### Put combined data into a data frame

tls1 = np.concatenate([i['new_mjd_1'][lc_indices(i, n_sigmas=n_sigs1, mJyas2_lms=mJyas2_lms1)] for i in df_list1])
fls1 = np.concatenate([i['new_mJyas2_1'][lc_indices(i, n_sigmas=n_sigs1, mJyas2_lms=mJyas2_lms1)] for i in df_list1])
ferrls1 = np.concatenate([i['new_mJyas2_err_1'][lc_indices(i, n_sigmas=n_sigs1, mJyas2_lms=mJyas2_lms1)] for i in df_list1])

# tls1 = np.concatenate([i['new_mjd_1'] for i in df_list1])
# fls1 = np.concatenate([i['new_mJyas2_1'] for i in df_list1])
# ferrls1 = np.concatenate([i['new_mJyas2_err_1'] for i in df_list1])

ord_inds1 = tls1.argsort()
tls1 = tls1[ord_inds1]
fls1 = fls1[ord_inds1]
ferrls1 = ferrls1[ord_inds1]

comb1_data = {'mjd': tls1, 'mJyas2': fls1, 'mJyas2_err': ferrls1}
comb1 = pdastrostatsclass()
comb1.t = comb1.t.assign(**comb1_data)



### Use sigmacutloop function in pdastro to calculate the combined light curve

# bins1, t_bvals1 = get_bins(comb1, tls1)
bins1 = get_LCbins(comb1,30)
tmed1 = []
fmed1 = []
fmed_err1 = []
workinds1 = []
badinds1 = []

for i in range(len(bins1)):
    bin_i = bins1[i]
    comb1.calcaverage_sigmacutloop('mJyas2', indices=bin_i, noisecol='mJyas2_err', percentile_cut_firstiteration=70, Nsigma=3.0)
    tmed1.append(np.average(comb1.t.loc[bin_i,'mjd'], weights=1-comb1.t.loc[bin_i,'mJyas2_err']/max(comb1.t.loc[bin_i,'mJyas2_err'])))
    fmed1.append(comb1.statparams['mean'])
    fmed_err1.append(comb1.statparams['mean_err'])
    workinds1.append(comb1.statparams['ix_good'])
    badinds1.append(comb1.statparams['ix_clip'])


tmed1 = np.array(tmed1)
fmed1 = np.array(fmed1)
fmed_err1 = np.array(fmed_err1)


### Find the peaks in combined light curve

tpeak1 = find_t_peak(tmed1, fmed1)

# %%
### Plot the combined light curve

pl_fig, pl_ax = plt.subplots(dpi = 100, figsize = [12,6])
pl_ax.minorticks_on()
pl_ax.tick_params(axis='x', labelsize=12)
pl_ax.tick_params(axis='y', labelsize=12)
pl_ax.tick_params(which='major',bottom='on',top='on',left='on',right='on',length=12)
pl_ax.tick_params(which='minor',bottom='on',top='on',left='on',right='on',length=5)
pl_ax.set_xlabel('MJD (days)', fontsize = 14)
pl_ax.set_ylabel('$\mu$Jy/as$^2$', fontsize = 14)
# pl_ax.set_title('Light Curve of filter i', x=0.4, y=0.9, fontsize = 16)
pl_ax.ticklabel_format(axis='both', style='plain')

winds1 = [i for bn in workinds1 for i in bn]

pl_ax.errorbar(comb1.t.loc[winds1,'mjd'], comb1.t.loc[winds1,'mJyas2'], fmt='.-', color='blue', alpha=0.25)
pl_ax.axhline(y=0, linestyle='--', color='black')
pl_ax.errorbar(tmed1, fmed1, fmt='--o', ecolor='black', color='orange') #,yerr=fmed_err1
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# ### Segment 2

# %%
### Read in light curves -- ec0915 ccd 54, focused on big peak

# url2 = 'https://stsci-transients.stsci.edu/eta/etalc/results/rod_test/goodpos_i/ec0915/54/ec0915a54_goodpos_i_tmpl296582.html'
# html2 = requests.get(url2).content
# df_table2 = pd.read_html(html2)[-1]

url2 = 'https://stsci-transients.stsci.edu/eta/etalc/results/rod_test/goodpos_i/ec0915/54/ec0915a54_goodpos_i_tmpl523435.html'
html2 = requests.get(url2).content
df_table2 = pd.read_html(html2)[-1]

groups2 = [0, 1, 2, 3, 4]
## 0 - comet, 1 - main peak, 2 - broad LCs, 3 - Armins, 4 - Armins test

df_list2 = []
df_table2_inds2 = []
for i in range(len(df_table2)):
    group_i = df_table2['group'][i]
    ID_i = df_table2['ID'][i]

    if group_i == 1:
        url = 'https://stsci-transients.stsci.edu/eta/etalc/results/rod_test/goodpos_i/ec0915/54/ec0915a54_goodpos_i_tmpl523435_ID'+str(ID_i)+'_lc.txt'
        temp_tab = pd.read_csv(url, sep='\s+')
        df_list2.append(temp_tab)
        df_table2_inds2.append(i)


### Want to work with micro-Jansky
for df in df_list2:
    df['mJyas2'] = df['Jyas2']*1e6
    df['mJyas2_err'] = df['Jyas2_err']*1e6

# %%
### Loop through and see the individual light curves
### Figure out uncertainty cuts to find the peaks

n_sigs2 = None       
mJyas2_lms2 = [50.0,1.0] 


# for i in df_list2:
#     df = i
#     print(df['ID'][0])
    
#     # plt.errorbar(df['mjd'], df['mJyas2'], yerr=df['mJyas2_err'], fmt='o', ecolor='black', color='blue')

#     inds_sig = lc_indices(df, n_sigmas=n_sigs2, mJyas2_lms=mJyas2_lms2, bad_expnums=bad_expnums_i)
#     plt.errorbar(df['mjd'][inds_sig], df['mJyas2'][inds_sig], yerr=df['mJyas2_err'][inds_sig], fmt='--o', ecolor='black', color='orange')
    
#     plt.axhline(y=0, linestyle='--', color='black')

#     # peak_t2 = find_t_peak(df['mjd'][inds_sig].values, df['mJyas2'][inds_sig].values)
#     # plt.axvline(x=peak_t2,color='red')
    
#     plt.show()

# %%
# Find the shift and fitting parameters for each light curve compared to the first one

temp_i = np.where(df_table2.loc[df_table2_inds2,'ID']==34)[0][0]
temp_ID = df_list2[temp_i]['ID'][0]
g1_inds = lc_indices(df_list2[temp_i], n_sigmas=n_sigs2, mJyas2_lms=mJyas2_lms2, bad_expnums=bad_expnums_i)
t1 = df_list2[temp_i]['mjd'][g1_inds].values
f1 = df_list2[temp_i]['mJyas2'][g1_inds].values
f1_err = df_list2[temp_i]['mJyas2_err'][g1_inds].values


fig, axs = plt.subplots(9, 6, figsize=(20, 40))
axs = axs.flatten() 

tshifts_54 = []
a_norms_54 = []
b_offsets_54 = []

for i, df in enumerate(df_list2):
    g_inds = lc_indices(df, n_sigmas=n_sigs2, mJyas2_lms=mJyas2_lms2, bad_expnums=bad_expnums_i)
    t2 = df['mjd'][g_inds].values
    f2 = df['mJyas2'][g_inds].values
    f2_err = df['mJyas2_err'][g_inds].values

    tshift, a, b = get_tshift_scale_offset(t1, f1, f1_err, t2, f2, f2_err)

    tshifts_54.append(tshift)
    a_norms_54.append(a)
    b_offsets_54.append(b)
    
    ax = axs[i]
    ax.plot(t1, f1, label='lc tmp')
    ax.plot(t2, f2, label='lc')
    ax.plot(t2-tshift, f2*a + b, alpha=.5, label='lc aligned')

    #-------
    # ax.axvline(x=57452, color='k', linewidth=.2)
    # ax.axvline(x=56745, color='k', linewidth=.2, label='tmpl')
    ax.axhline(y=0, color='k', linewidth=.2)

    i_ID = str(df['ID'][0])
    ax.legend()
    ax.set_title(f'ID={i_ID}')

plt.show()

# %%
# Find the shift and fitting parameters for each light curve compared to the first one

for i in range(len(tshifts_54)):
    df = df_list2[i]
    i_inds = lc_indices(df, n_sigmas=n_sigs2, mJyas2_lms=mJyas2_lms2, bad_expnums=bad_expnums_i)
    
    tshift_i = tshifts_54[i]
    a_i = a_norms_54[i]
    b_i = b_offsets_54[i]
    
    t_new = df['mjd'][i_inds] - tshift_i
    f_new = a_i*df['mJyas2'][i_inds]+b_i
    ferr_new = a_i*df['mJyas2_err'][i_inds]
    df.loc[i_inds,'new_mjd_1'] = t_new
    df.loc[i_inds,'new_mJyas2_1'] = f_new
    df.loc[i_inds,'new_mJyas2_err_1'] = ferr_new

    # t_new = df['mjd'] - tshift_i
    # f_new = a_i*df['mJyas2']+b_i
    # ferr_new = a_i*df['mJyas2_err']
    # df['new_mjd_1'] = t_new
    # df['new_mJyas2_1'] = f_new
    # df['new_mJyas2_err_1'] = ferr_new
    
    plt.errorbar(t_new, f_new, yerr=ferr_new, fmt='.-', ecolor='black')
    # plt.ylim(-3.0e-6,4.0e-6)
# plt.xlim(57650,57800)

# %%
### Put combined data into a data frame
tls2 = np.concatenate([i['new_mjd_1'][lc_indices(i, n_sigmas=n_sigs2, mJyas2_lms=mJyas2_lms2, bad_expnums=bad_expnums_i)] for i in df_list2])
fls2 = np.concatenate([i['new_mJyas2_1'][lc_indices(i, n_sigmas=n_sigs2, mJyas2_lms=mJyas2_lms2, bad_expnums=bad_expnums_i)] for i in df_list2])
ferrls2 = np.concatenate([i['new_mJyas2_err_1'][lc_indices(i, n_sigmas=n_sigs2, mJyas2_lms=mJyas2_lms2, bad_expnums=bad_expnums_i)] for i in df_list2])

# tls2 = np.concatenate([i['new_mjd_1'][lc_indices(i, bad_expnums=bad_expnums_i)] for i in df_list2])
# fls2 = np.concatenate([i['new_mJyas2_1'][lc_indices(i, bad_expnums=bad_expnums_i)] for i in df_list2])
# ferrls2 = np.concatenate([i['new_mJyas2_err_1'][lc_indices(i, bad_expnums=bad_expnums_i)] for i in df_list2])

ord_inds2 = tls2.argsort()
tls2 = tls2[ord_inds2]
fls2 = fls2[ord_inds2]
ferrls2 = ferrls2[ord_inds2]


comb2_data = {'mjd': tls2, 'mJyas2': fls2, 'mJyas2_err': ferrls2}
comb2 = pdastrostatsclass()
comb2.t = comb2.t.assign(**comb2_data)



### Use sigmacutloop function in pdastro to calculate the combined light curve
# bins2, t_bvals2 = get_bins(comb2, tls2)
bins2 = get_LCbins(comb2,30)
tmed2 = []
fmed2 = []
fmed_err2 = []
workinds2 = []
badinds2 = []

for i in range(len(bins2)):
    print
    bin_i = bins2[i]
    comb2.calcaverage_sigmacutloop('mJyas2', indices=bin_i, noisecol='mJyas2_err', percentile_cut_firstiteration=70, Nsigma=3.0)
    tmed2.append(np.average(comb2.t.loc[bin_i,'mjd'], weights=1-comb2.t.loc[bin_i,'mJyas2_err']/max(comb2.t.loc[bin_i,'mJyas2_err'])))
    fmed2.append(comb2.statparams['mean'])
    fmed_err2.append(comb2.statparams['mean_err'])
    workinds2.append(comb2.statparams['ix_good'])
    badinds2.append(comb2.statparams['ix_clip'])


tmed2 = np.array(tmed2)
fmed2 = np.array(fmed2)
fmed_err2 = np.array(fmed_err2)


### Find the peaks in combined light curve
tpeak2 = find_t_peak(tmed2, fmed2)

# %%
### Plot the combined light curve

pl_fig, pl_ax = plt.subplots(dpi = 100, figsize = [12,6])
pl_ax.minorticks_on()
pl_ax.tick_params(axis='x', labelsize=12)
pl_ax.tick_params(axis='y', labelsize=12)
pl_ax.tick_params(which='major',bottom='on',top='on',left='on',right='on',length=12)
pl_ax.tick_params(which='minor',bottom='on',top='on',left='on',right='on',length=5)
pl_ax.set_xlabel('MJD (days)', fontsize = 14)
pl_ax.set_ylabel('$\mu$Jy/as$^2$', fontsize = 14)
pl_ax.ticklabel_format(axis='both', style='plain')

winds2 = [i for bn in workinds2 for i in bn]

pl_ax.errorbar(comb2.t.loc[winds2,'mjd'], comb2.t.loc[winds2,'mJyas2'], color='blue', fmt='.-', alpha=0.25)
pl_ax.axhline(y=0, linestyle='--', color='black')
pl_ax.errorbar(tmed2,fmed2, fmt='--o', ecolor='black', color='orange') #,yerr=fmed_err2
pl_ax.axvline(x=tpeak2, color='red', linestyle='--')
# pl_fig.savefig('ec0915_LC2.png', bbox_inches = 'tight', dpi=100)

# %% [markdown]
# ### Segment 3

# %%
### Read in light curves -- Armin positions, focused on plateau

groups2 = [0, 1, 2, 3, 4]
## 0 - comet, 1 - main peak, 2 - broad LCs, 3 - Armins, 4 - Armins test

df_list3 = []
df_table2_inds3 = []
for i in range(len(df_table2)):
    group_i = df_table2['group'][i]
    ID_i = df_table2['ID'][i]

    if group_i == 3:
        url = 'https://stsci-transients.stsci.edu/eta/etalc/results/rod_test/goodpos_i/ec0915/54/ec0915a54_goodpos_i_tmpl523435_ID'+str(ID_i)+'_lc.txt'
        temp_tab = pd.read_csv(url, sep='\s+')
        df_list3.append(temp_tab)
        df_table2_inds3.append(i)


for df in df_list3:
    df['mJyas2'] = df['Jyas2']*1e6
    df['mJyas2_err'] = df['Jyas2_err']*1e6

# %%
### Loop through and see the individual light curves
### Figure out uncertainty cuts to find the peaks

n_sigs3 = None
mJyas2_lms3 = [5.0,1.0]

# for df in df_list3:
#     print(df['ID'][0])
    
#     # plt.errorbar(df['mjd'], df['Jyas2'], yerr=df['Jyas2_err'], fmt='o', ecolor='black', color='blue')

#     inds_sig = lc_indices(df, n_sigmas=n_sigs3, mJyas2_lms=mJyas2_lms3, bad_expnums=bad_expnums_i)
#     plt.errorbar(df['mjd'][inds_sig], df['Jyas2'][inds_sig], yerr=df['Jyas2_err'][inds_sig], fmt='--o', ecolor='black', color='orange')
    
#     plt.axhline(y=0, linestyle='--', color='black')

#     # peak_t3 = find_t_peak(df['mjd'][inds_sig].values, df['Jyas2'][inds_sig].values)
#     # plt.axvline(x=peak_t3,color='red')
    
#     plt.show()

t_peaks_locs = [57500, 57500, 57400, 57800]

# %%
# Find the shift and fitting parameters for each light curve compared to the first one

temp_i = 0
temp_ID = df_list3[temp_i]['ID'][0]
g1_inds = lc_indices(df_list3[temp_i], n_sigmas=n_sigs3, mJyas2_lms=mJyas2_lms3, bad_expnums=bad_expnums_i)
t1 = df_list3[temp_i]['mjd'][g1_inds].values
f1 = df_list3[temp_i]['mJyas2'][g1_inds].values
f1_err = df_list3[temp_i]['mJyas2_err'][g1_inds].values
tp_loc1 = t_peaks_locs[0]


fig, axs = plt.subplots(1, 4, figsize=(20, 5))
axs = axs.flatten() 

tshifts_A = []
a_norms_A = []
b_offsets_A = []

for i, df in enumerate(df_list3):
    g_inds = lc_indices(df, n_sigmas=n_sigs3, mJyas2_lms=mJyas2_lms3, bad_expnums=bad_expnums_i)
    t2 = df['mjd'][g_inds].values
    f2 = df['mJyas2'][g_inds].values
    f2_err = df['mJyas2_err'][g_inds].values
    tp_loc2 = t_peaks_locs[i]

    tshift, a, b = get_tshift_scale_offset(t1, f1, f1_err, t2, f2, f2_err, t_peaks=[tp_loc1, tp_loc2])

    tshifts_A.append(tshift)
    a_norms_A.append(a)
    b_offsets_A.append(b)
    
    ax = axs[i]
    ax.plot(t1, f1, label='lc tmp')
    ax.plot(t2, f2, label='lc')
    ax.plot(t2-tshift, f2*a + b, alpha=.5, label='lc aligned')

    #-------
    # ax.axvline(x=57452, color='k', linewidth=.2)
    # ax.axvline(x=56745, color='k', linewidth=.2, label='tmpl')
    ax.axhline(y=0, color='k', linewidth=.2)

    i_ID = str(df['ID'][0])
    ax.legend()
    ax.set_title(f'ID={i_ID}')

plt.show()

# %%
# Find the shift and fitting parameters for each light curve compared to the first one

for i in range(len(tshifts_A)):
    df = df_list3[i]
    i_inds = lc_indices(df, n_sigmas=n_sigs3, mJyas2_lms=mJyas2_lms3, bad_expnums=bad_expnums_i)
    
    tshift_i = tshifts_A[i]
    a_i = a_norms_A[i]
    b_i = b_offsets_A[i]
    
    t_new = df['mjd'][i_inds] - tshift_i
    f_new = a_i*df['mJyas2'][i_inds]+b_i
    ferr_new = a_i*df['mJyas2_err'][i_inds]
    df.loc[i_inds,'new_mjd_1'] = t_new
    df.loc[i_inds,'new_mJyas2_1'] = f_new
    df.loc[i_inds,'new_mJyas2_err_1'] = ferr_new
    
    plt.errorbar(t_new, f_new, yerr=ferr_new, fmt='.-', ecolor='black')
    # plt.ylim(-3.0e-6,4.0e-6)
# plt.xlim(57650,57800)

# %%
### Put combined data into a data frame

tls3 = np.concatenate([i['new_mjd_1'][lc_indices(i, n_sigmas=n_sigs3, mJyas2_lms=mJyas2_lms3, bad_expnums=bad_expnums_i)] for i in df_list3])
fls3 = np.concatenate([i['new_mJyas2_1'][lc_indices(i, n_sigmas=n_sigs3, mJyas2_lms=mJyas2_lms3, bad_expnums=bad_expnums_i)] for i in df_list3])
ferrls3 = np.concatenate([i['new_mJyas2_err_1'][lc_indices(i, n_sigmas=n_sigs3, mJyas2_lms=mJyas2_lms3, bad_expnums=bad_expnums_i)] for i in df_list3])

ord_inds3 = tls3.argsort()
tls3 = tls3[ord_inds3]
fls3 = fls3[ord_inds3]
ferrls3 = ferrls3[ord_inds3]


comb3_data = {'mjd': tls3, 'mJyas2': fls3, 'mJyas2_err': ferrls3}
comb3 = pdastrostatsclass()
comb3.t = comb3.t.assign(**comb3_data)


### Use sigmacutloop function in pdastro to calculate the combined light curve
# bins3, t_bvals3 = get_bins(comb3, tls3)
bins3 = get_LCbins(comb3,30)
tmed3 = []
fmed3 = []
fmed_err3 = []
workinds3 = []
badinds3 = []

for i in range(len(bins3)):
    bin_i = bins3[i]
    comb3.calcaverage_sigmacutloop('mJyas2', indices=bin_i, noisecol='mJyas2_err', percentile_cut_firstiteration=70, Nsigma=3.0)
    tmed3.append(np.average(comb3.t.loc[bin_i,'mjd'], weights=1-comb3.t.loc[bin_i,'mJyas2_err']/max(comb3.t.loc[bin_i,'mJyas2_err'])))
    fmed3.append(comb3.statparams['mean'])
    fmed_err3.append(comb3.statparams['mean_err'])
    workinds3.append(comb3.statparams['ix_good'])
    badinds3.append(comb3.statparams['ix_clip'])


tmed3 = np.array(tmed3)
fmed3 = np.array(fmed3)
fmed_err3 = np.array(fmed_err3)

# %%
### Plot the combined light curve

pl_fig, pl_ax = plt.subplots(dpi = 100, figsize = [12,6])
pl_ax.minorticks_on()
pl_ax.tick_params(axis='x', labelsize=12)
pl_ax.tick_params(axis='y', labelsize=12)
pl_ax.tick_params(which='major',bottom='on',top='on',left='on',right='on',length=12)
pl_ax.tick_params(which='minor',bottom='on',top='on',left='on',right='on',length=5)
pl_ax.set_xlabel('MJD (days)', fontsize = 14)
pl_ax.set_ylabel('$\mu$Jy/as$^2$', fontsize = 14)
pl_ax.ticklabel_format(axis='both', style='plain')

winds3 = [i for bn in workinds3 for i in bn]

pl_ax.errorbar(comb3.t.loc[winds3,'mjd'], comb3.t.loc[winds3,'mJyas2'], color='blue', fmt='.-', alpha=0.25)
pl_ax.axhline(y=0, linestyle='--', color='black')
pl_ax.errorbar(tmed3,fmed3, fmt='--o', ecolor='black', color='orange') #,yerr=fmed_err3

# pl_fig.savefig('ec0915_LC3.png', bbox_inches = 'tight', dpi=100)
plt.axvline(x=57500)

# %% [markdown]
# ### Segment 4

# %%
### Read in light curves -- ec0915 ccd 54 (comet), focused on tail end

groups2 = [0, 1, 2, 3, 4]
## 0 - comet, 1 - main peak, 2 - broad LCs, 3 - Armins, 4 - Armins test

df_list4 = []
df_table2_inds4 = []
for i in range(len(df_table2)):
    group_i = df_table2['group'][i]
    ID_i = df_table2['ID'][i]

    if group_i == 0:
        url = 'https://stsci-transients.stsci.edu/eta/etalc/results/rod_test/goodpos_i/ec0915/54/ec0915a54_goodpos_i_tmpl523435_ID'+str(ID_i)+'_lc.txt'
        temp_tab = pd.read_csv(url, sep='\s+')
        df_list4.append(temp_tab)
        df_table2_inds4.append(i)


### Want to work with micro-Jansky
for df in df_list4:
    df['mJyas2'] = df['Jyas2']*1e6
    df['mJyas2_err'] = df['Jyas2_err']*1e6

# %%
### Loop through and see the individual light curves
### Figure out uncertainty cuts

n_sigs4 = None
# n_sigs4 = [10.0, 1.0]
mJyas2_lms4 = [5.0, 1.0]

# for df in df_list4:
#     print(df['ID'][0])
    
#     # plt.errorbar(df['mjd'], df['mJyas2'], yerr=df['mJyas2_err'], fmt='o', ecolor='black', color='blue')

#     inds_sig = lc_indices(df, n_sigmas=n_sigs4, mJyas2_lms=mJyas2_lms4, bad_expnums=bad_expnums_i)
#     plt.errorbar(df['mjd'][inds_sig], df['mJyas2'][inds_sig], yerr=df['mJyas2_err'][inds_sig], fmt='--o', ecolor='black', color='orange')
    
#     plt.axhline(y=0, linestyle='--', color='black')

#     peak_t4 = find_t_peak(df['mjd'][inds_sig].values, df['mJyas2'][inds_sig].values, t_range=[57200,57900])
#     plt.axvline(x=peak_t4,color='red')
#     # plt.axvline(x=57800,color='magenta')
    
#     print(peak_t4)
#     plt.show()

# %%
# Find the shift and fitting parameters for each light curve compared to the segment 1
temp_i = 0
temp_ID = df_list4[temp_i]['ID'][0]
g1_inds = lc_indices(df_list4[temp_i], n_sigmas=n_sigs4, mJyas2_lms=mJyas2_lms4, bad_expnums=bad_expnums_i)
t1 = df_list4[temp_i]['mjd'][g1_inds].values
f1 = df_list4[temp_i]['mJyas2'][g1_inds].values
f1_err = df_list4[temp_i]['mJyas2_err'][g1_inds].values


fig, axs = plt.subplots(5, 6, figsize=(20, 10))
axs = axs.flatten() 

tshifts_c = []
a_norms_c = []
b_offsets_c = []

for i, df in enumerate(df_list4):
    g_inds = lc_indices(df, n_sigmas=n_sigs4, mJyas2_lms=mJyas2_lms4, bad_expnums=bad_expnums_i)
    t2 = df['mjd'][g_inds].values
    f2 = df['mJyas2'][g_inds].values
    f2_err = df['mJyas2_err'][g_inds].values

    tshift, a, b = get_tshift_scale_offset(t1, f1, f1_err, t2, f2, f2_err, t_peaks=[t1[-1],t2[-1]])
    
    tshifts_c.append(tshift)
    a_norms_c.append(a)
    b_offsets_c.append(b)
    
    ax = axs[i]
    ax.plot(t1, f1, label='lc tmp')
    ax.errorbar(t2, f2, label='lc', fmt='.-')
    ax.errorbar(t2-tshift, f2*a + b, alpha=.5, label='lc aligned', fmt='.-')

    #-------
    # ax.axvline(x=57452, color='k', linewidth=.2)
    # ax.axvline(x=56745, color='k', linewidth=.2, label='tmpl')
    ax.axhline(y=0, color='k', linewidth=.2)

    i_ID = str(df['ID'][0])
    ax.legend()
    ax.set_title(f'ID={i_ID}')

plt.show()

# %%
for i in range(len(tshifts_c)):
    df = df_list4[i]
    i_inds = lc_indices(df, n_sigmas=n_sigs4, mJyas2_lms=mJyas2_lms4, bad_expnums=bad_expnums_i)
    
    tshift_i = tshifts_c[i]
    a_i = a_norms_c[i]
    b_i = b_offsets_c[i]
    t_new = df['mjd'][i_inds] - tshift_i
    f_new = a_i*df['mJyas2'][i_inds]+b_i
    ferr_new = a_i*df['mJyas2_err'][i_inds]
    df.loc[i_inds,'new_mjd_1'] = t_new
    df.loc[i_inds,'new_mJyas2_1'] = f_new
    df.loc[i_inds,'new_mJyas2_err_1'] = ferr_new
    plt.errorbar(t_new, f_new, yerr=ferr_new, fmt='.-', ecolor='black')
    # plt.ylim(-3.0e-6,4.0e-6)
# plt.xlim(57650,57800)

# %%
### Put combined data into a data frame
tls4 = np.concatenate([i['new_mjd_1'][lc_indices(i, n_sigmas=n_sigs4, mJyas2_lms=mJyas2_lms4, bad_expnums=bad_expnums_i)] for i in df_list4])
fls4 = np.concatenate([i['new_mJyas2_1'][lc_indices(i, n_sigmas=n_sigs4, mJyas2_lms=mJyas2_lms4, bad_expnums=bad_expnums_i)] for i in df_list4])
ferrls4 = np.concatenate([i['new_mJyas2_err_1'][lc_indices(i, n_sigmas=n_sigs4, mJyas2_lms=mJyas2_lms4, bad_expnums=bad_expnums_i)] for i in df_list4])

ord_inds4 = tls4.argsort()
tls4 = tls4[ord_inds4]
fls4 = fls4[ord_inds4]
ferrls4 = ferrls4[ord_inds4]


comb4_data = {'mjd': tls4, 'mJyas2': fls4, 'mJyas2_err': ferrls4}
comb4 = pdastrostatsclass()
comb4.t = comb4.t.assign(**comb4_data)



### Use sigmacutloop function in pdastro to calculate the combined light curve
# bins4, t_bvals4 = get_bins(comb4, tls4)
bins4 = get_LCbins(comb4, 30)
tmed4 = []
fmed4 = []
fmed_err4 = []
workinds4 = []
badinds4 = []

for i in range(len(bins4)):
    bin_i = bins4[i]
    comb4.calcaverage_sigmacutloop('mJyas2', indices=bin_i, noisecol='mJyas2_err', percentile_cut_firstiteration=70, Nsigma=3.0)
    tmed4.append(np.average(comb4.t.loc[bin_i,'mjd'], weights=1-comb4.t.loc[bin_i,'mJyas2_err']/max(comb4.t.loc[bin_i,'mJyas2_err'])))
    fmed4.append(comb4.statparams['mean'])
    fmed_err4.append(comb4.statparams['mean_err'])
    workinds4.append(comb4.statparams['ix_good'])
    badinds4.append(comb4.statparams['ix_clip'])


tmed4 = np.array(tmed4)
fmed4 = np.array(fmed4)
fmed_err4 = np.array(fmed_err4)

# %%
### Plot the combined light curve

pl_fig, pl_ax = plt.subplots(dpi = 100, figsize = [12,6])
pl_ax.minorticks_on()
pl_ax.tick_params(axis='x', labelsize=12)
pl_ax.tick_params(axis='y', labelsize=12)
pl_ax.tick_params(which='major',bottom='on',top='on',left='on',right='on',length=12)
pl_ax.tick_params(which='minor',bottom='on',top='on',left='on',right='on',length=5)
pl_ax.set_xlabel('MJD (days)', fontsize = 14)
pl_ax.set_ylabel('$\mu$Jy/as$^2$', fontsize = 14)
pl_ax.ticklabel_format(axis='both', style='plain')

winds4 = [i for bn in workinds4 for i in bn]
f_offset = 1.0

pl_ax.errorbar(comb4.t.loc[winds4,'mjd'], comb4.t.loc[winds4,'mJyas2']+f_offset, color='blue', fmt='.-', alpha=0.25)
pl_ax.axhline(y=0, linestyle='--', color='black')
pl_ax.errorbar(tmed4,fmed4+f_offset, fmt='--o', ecolor='black', color='orange') #,yerr=fmed_err4

# pl_fig.savefig('ec0915_LC4.png', bbox_inches = 'tight', dpi=100)
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# ### Combine Segments -- Get LC_0 (the model)

# %%
### Plot all the segments

pl_fig, pl_ax = plt.subplots(dpi = 100, figsize = [8,5])
pl_ax.minorticks_on()
pl_ax.tick_params(axis='x', labelsize=12)
pl_ax.tick_params(axis='y', labelsize=12)
pl_ax.tick_params(which='major',bottom='on',top='on',left='on',right='on',length=12)
pl_ax.tick_params(which='minor',bottom='on',top='on',left='on',right='on',length=5)
pl_ax.set_xlabel('MJD (days)', fontsize = 14)
pl_ax.set_ylabel('$\mu$Jy/as$^2$ + arbit.', fontsize = 14)
# pl_ax.set_title('Light Curve of filter i', x=0.4, y=0.9, fontsize = 16)
pl_ax.ticklabel_format(axis='both', style='plain')

# pl_ax.scatter(comb1.t.loc[:,'mjd'], comb1.t.loc[:,'Jyas2'], color='blue', alpha=0.25)
# pl_ax.scatter(comb2.t.loc[:,'mjd'], comb2.t.loc[:,'Jyas2'], color='green', alpha=0.25)
# pl_ax.scatter(comb3.t.loc[:,'mjd'], comb3.t.loc[:,'Jyas2'], color='orange', alpha=0.25)
# pl_ax.scatter(comb4.t.loc[:,'mjd'], comb4.t.loc[:,'Jyas2'], color='red', alpha=0.25)
# pl_ax.axhline(y=0, linestyle='--', color='black')

pl_ax.errorbar(tmed1, 3*fmed1-50, fmt='.-', ecolor='black', color='deepskyblue', label='Section 1')
pl_ax.errorbar(tmed2, fmed2, fmt='.-', ecolor='black', color='mediumseagreen', label='Section 2')
pl_ax.errorbar(tmed3, 5*fmed3 - 65, fmt='.-', ecolor='black', color='red', label='Section 3')
pl_ax.errorbar(tmed4, 5*fmed4 - 85, fmt='.-', ecolor='black', color='orange', label='Section 4')

pl_ax.legend()

# pl_fig.savefig('../figures/display/EtaCar_iLCmodels.png', bbox_inches = 'tight', dpi=100)

pl_ax.axvline(x=60700)

# %%
tshiftm21, am21, bm21 = get_tshift_scale_offset(tmed2, fmed2, fmed_err2, tmed1, fmed1, fmed_err1)

tpeakm23 = [59325, 57500]
tshiftm23, am23, bm23 = get_tshift_scale_offset(tmed2, fmed2, fmed_err2, tmed3, fmed3, fmed_err3, t_peaks=tpeakm23)

# tpeakm24 = [60700, tmed4[0]]
# tshiftm24, am24, bm24 = get_tshift_scale_offset(tmed2, fmed2, fmed_err2, tmed4, fmed4, fmed_err4, t_peaks=tpeakm24)

# %%
offsetm = 66.

m_t1 = tmed1-tshiftm21
m_f1 = (am21*fmed1+bm21)+offsetm
m_ferr1 = am21*fmed_err1

m_t2 = tmed2
m_f2 = fmed2+offsetm
m_ferr2 = fmed_err2

m_t3 = tmed3-tshiftm23
m_f3 = (am23*fmed3+bm23)+offsetm
m_ferr3 = am23*fmed_err3

m_t4 = tmed4+4500
m_f4 = (3.0*fmed4-43.5)+offsetm
m_ferr4 = 3.0*fmed_err4


pl_fig, pl_ax = plt.subplots(dpi = 100, figsize = [8,5])
pl_ax.minorticks_on()
pl_ax.tick_params(axis='x', labelsize=12)
pl_ax.tick_params(axis='y', labelsize=12)
pl_ax.tick_params(which='major',bottom='on',top='on',left='on',right='on',length=12)
pl_ax.tick_params(which='minor',bottom='on',top='on',left='on',right='on',length=5)
pl_ax.set_xlabel('MJD (days)', fontsize = 14)
pl_ax.set_ylabel('$\mu$Jy/as$^2$', fontsize = 14)
# pl_ax.set_title('Light Curve of filter i', x=0.4, y=0.9, fontsize = 16)
pl_ax.ticklabel_format(axis='both', style='plain')


pl_ax.axhline(y=0, linestyle='--', color='black')

pl_ax.errorbar(m_t1, m_f1, fmt='--o', ecolor='black', color='deepskyblue', label='Section 1')
pl_ax.errorbar(m_t2, m_f2, fmt='--o', ecolor='black', color='mediumseagreen', label='Section 2')
pl_ax.errorbar(m_t3, m_f3, fmt='--o', ecolor='black', color='red', label='Section 3')
pl_ax.errorbar(m_t4, m_f4, fmt='--o', ecolor='black', color='orange', label='Section 4')


# pl_fig.savefig('../figures/display/EtaCar_Model1.png', bbox_inches = 'tight', dpi=100)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
model_t = np.concatenate([m_t1, m_t2, m_t3, m_t4])
model_f = np.concatenate([m_f1, m_f2, m_f3, m_f4])
model_ferr = np.concatenate([m_ferr1, m_ferr2, m_ferr3, m_ferr4])


ord_inds = model_t.argsort()
model_t = model_t[ord_inds]
model_f = model_f[ord_inds]
model_ferr = model_ferr[ord_inds]

# %%
fin_t1 = comb1.t.loc[winds1,'mjd'].values-tshiftm21
fin_f1 = (am21*comb1.t.loc[winds1,'mJyas2'].values+bm21)+offsetm
fin_ferr1 = am21*comb1.t.loc[winds1,'mJyas2_err'].values

fin_t2 = comb2.t.loc[winds2,'mjd'].values
fin_f2 = comb2.t.loc[winds2,'mJyas2'].values+offsetm
fin_ferr2 = comb2.t.loc[winds2,'mJyas2_err'].values

fin_t3 = comb3.t.loc[winds3,'mjd'].values-tshiftm23
fin_f3 = (am23*comb3.t.loc[winds3,'mJyas2'].values+bm23)+offsetm
fin_ferr3 = am23*comb3.t.loc[winds3,'mJyas2_err'].values

fin_t4 = comb4.t.loc[winds4,'mjd'].values+4500
fin_f4 = (3.0*comb4.t.loc[winds4,'mJyas2'].values-43.5)+offsetm
fin_ferr4 = 3.0*comb4.t.loc[winds4,'mJyas2_err'].values


tlsm = np.concatenate([fin_t1, fin_t2, fin_t3, fin_t4])
flsm = np.concatenate([fin_f1, fin_f2, fin_f3, fin_f4])
ferrlsm = np.concatenate([fin_ferr1, fin_ferr2, fin_ferr3, fin_ferr4])


ord_indsm = tlsm.argsort()
tlsm = tlsm[ord_indsm]
flsm = flsm[ord_indsm]
ferrlsm = ferrlsm[ord_indsm]


combm_data = {'mjd': tlsm, 'mJyas2': flsm, 'mJyas2_err': ferrlsm}
combm = pdastrostatsclass()
combm.t = combm.t.assign(**combm_data)

# %%
# plt.subplots(dpi = 100, figsize = [12,6])
# plt.errorbar(combm.t['mjd'], combm.t['mJyas2'], fmt='.', ecolor='black', color='blue')
# plt.errorbar(model_t, model_f, fmt='--o', ecolor='black', color='orange')
# plt.axhline(y=0, linestyle='--', color='black')

# %%
binsm = get_LCbins(combm,30)
tmedm = []
fmedm = []
fmed_errm = []
workindsm = []
badindsm = []

for i in range(len(binsm)):
    bin_i = binsm[i]
    combm.calcaverage_sigmacutloop('mJyas2', indices=bin_i, noisecol='mJyas2_err', percentile_cut_firstiteration=70, Nsigma=3.0)
    tmedm.append(np.average(combm.t.loc[bin_i,'mjd'], weights=1-combm.t.loc[bin_i,'mJyas2_err']/max(combm.t.loc[bin_i,'mJyas2_err'])))
    fmedm.append(combm.statparams['mean'])
    fmed_errm.append(combm.statparams['mean_err'])
    workindsm.append(combm.statparams['ix_good'])
    badindsm.append(combm.statparams['ix_clip'])
    

tmedm = np.array(tmedm)
fmedm = np.array(fmedm)
fmed_errm = np.array(fmed_errm)

# %%
plt.subplots(dpi = 100, figsize = [12,6])
windsm = [i for bn in workindsm for i in bn]
plt.errorbar(combm.t.loc[windsm,'mjd'], combm.t.loc[windsm,'mJyas2'], fmt='.', ecolor='black', color='blue')
plt.errorbar(tmedm, fmedm, fmt='--o', ecolor='black', color='orange')
plt.axhline(y=0, linestyle='--', color='black')

# %%
# imodel = {'mjd':model_t, 'mJyas2':model_f, 'mJyas2_err':model_ferr}
imodel = {'mjd':tmedm, 'mJyas2':fmedm, 'mJyas2_err':fmed_errm}
imodel_d = pd.DataFrame(imodel)

# %%
imodel_d.to_csv('../tables/LC_tables/M1_iEtaCarLC.csv', index=False)
